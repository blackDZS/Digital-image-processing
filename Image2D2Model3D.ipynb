# %% [markdown]
# <a href="https://colab.research.google.com/github/blackDZS/Digital-image-processing/blob/master/Image2D2Model3D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.cvtColor(cv2.imread("./EF_000.jpeg"), cv2.COLOR_BGR2RGB)

# %%
plt.rcParams['figure.figsize'] = (15, 15) 
plt.imshow(img)
